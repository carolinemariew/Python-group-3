# %%
import pandas as pd
import chardet

import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook"

# %%
path_rail = './Python-group-3/Datasets/rail_pa_speed_page_linear.csv'
with open(path_rail, 'rb') as rawdata:
 result = chardet.detect(rawdata.read(100000))
result
df = pd.read_csv(path_rail, encoding ='Windows-1252')
df
# Out:
#                      DATAFLOW       LAST UPDATE freq unit   vehicle geo  \
# 0    ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  AL
# 1    ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  AL
# 2    ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  BG
# 3    ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  EE
# 4    ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  EE
# ..                        ...               ...  ...  ...       ...  ..
# 106  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  TR
# 107  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  XK
# 108  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  XK
# 109  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  XK
# 110  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  XK
#
#      TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0           2020        0.0      NaN
# 1           2021        0.0      NaN
# 2           2014        NaN        z
# 3           2014        NaN        z
# 4           2015        NaN        z
# ..           ...        ...      ...
# 106         2020     2833.0      NaN
# 107         2018        0.0      NaN
# 108         2019        0.0      NaN
# 109         2020        0.0      NaN
# 110         2021        0.0      NaN
#
# [111 rows x 9 columns]

# %%
path_air = './Python-group-3/Datasets/Air_transport_of_passengers_by_country.csv'
with open(path_air, 'rb') as rawdata:
 result = chardet.detect(rawdata.read(100000))
result
dh = pd.read_csv(path_air, encoding ='Windows-1252')
dh
# Out:
#                 DATAFLOW        LAST UPDATE freq unit tra_meas tra_cov  \
# 0    ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 1    ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 2    ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 3    ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 4    ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# ..                   ...                ...  ...  ...      ...     ...
# 398  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 399  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 400  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 401  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 402  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
#
#     schedule geo  TIME_PERIOD  OBS_VALUE  OBS_FLAG
# 0        TOT  AT         2011   25137612       NaN
# 1        TOT  AT         2012   25965977       NaN
# 2        TOT  AT         2013   25749724       NaN
# 3        TOT  AT         2014   26378676       NaN
# 4        TOT  AT         2015   26754007       NaN
# ..       ...  ..          ...        ...       ...
# 398      TOT  UK         2015  232270437       NaN
# 399      TOT  UK         2016  248868873       NaN
# 400      TOT  UK         2017  264629454       NaN
# 401      TOT  UK         2018  272190155       NaN
# 402      TOT  UK         2019  277432380       NaN
#
# [403 rows x 11 columns]

# %%
rail = df[df['geo']=="FR"] # the rail data in particular to France is taken from the main dataset
rail
# Out:
#                     DATAFLOW       LAST UPDATE freq unit   vehicle geo  \
# 24  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  FR
# 25  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  FR
# 26  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  FR
# 27  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  FR
# 28  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  FR
# 29  ESTAT:RAIL_PA_SPEED(1.0)  04-10-2023 23:00    A  PAS  TRN_HSPD  FR
#
#     TIME_PERIOD    OBS_VALUE OBS_FLAG
# 24         2016  283169000.0      NaN
# 25         2017  306890535.0      NaN
# 26         2018  297411278.0      NaN
# 27         2019  318934685.0      NaN
# 28         2020  190824019.0      NaN
# 29         2021  248285835.0      NaN

# %%
air_n = dh[dh['geo']=="FR"]  # similarly, air dataset for particularly France is taken 
air = air_n[air_n['TIME_PERIOD']>2015] # To keep synchronisation data from 2015 is taken 
air['WITHIN_FRANCE'] = air['OBS_VALUE'] * 0.23 # As per the data from European Union, an approximate of 23% of the all air travel is occuring within the nation, that is the domestic flights
air
# Out:
# C:\Users\vedan\AppData\Local\Temp\ipykernel_10732\3342833554.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 DATAFLOW        LAST UPDATE freq unit tra_meas tra_cov  \
# 162  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 163  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 164  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 165  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 166  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 167  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
# 168  ESTAT:TTR00012(1.0)  05/10/23 23:00:00    A  PAS  PAS_CRD   TOTAL
#
#     schedule geo  TIME_PERIOD  OBS_VALUE  OBS_FLAG  WITHIN_FRANCE
# 162      TOT  FR         2016  145280602       NaN    33414538.46
# 163      TOT  FR         2017  154096485       NaN    35442191.55
# 164      TOT  FR         2018  161991179       NaN    37257971.17
# 165      TOT  FR         2019  168726788       NaN    38807161.24
# 166      TOT  FR         2020   50724011       NaN    11666522.53
# 167      TOT  FR         2021   66033809       NaN    15187776.07
# 168      TOT  FR         2022  136560938       NaN    31409015.74

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(air['TIME_PERIOD'], air['WITHIN_FRANCE'], label='Air travel', marker='d')  # Both the Air travel and Train travel are compared for France.
ax.plot(rail['TIME_PERIOD'], rail['OBS_VALUE'], label='Railway travel', marker='s') # France is taken specifically due to the presence of High Speed Railway Network in the Country which is competative to the air travel

ax.set_xlabel('Year')
ax.set_ylabel('Total Passengers')
ax.set_title('Comparison for French Air and Railway passengers from 2016 until 2022')
ax.grid(True)
ax.legend()

plt.show()
